# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("raw_data.csv")

# %%
df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018                            NaN
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018                            NaN
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9     NaN                  NaN         NaN                            NaN
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %%
#Q1. insert 9th index.
df.loc[9]=[210,"Jim Carry","01/01/1970","jimcarry@gmail.com","Male","Amazon","USA",12349.556,2365]
df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018                            NaN
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018                            NaN
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9   210.0            Jim Carry  01/01/1970             jimcarry@gmail.com
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %%
#Q2. add email at 3,6 position
df.at[3,'email']= 'abc@gmail.com'
df.at[6,'email']= 'cdf@gmail.com'

# %%
df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018                  abc@gmail.com
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018                  cdf@gmail.com
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9   210.0            Jim Carry  01/01/1970             jimcarry@gmail.com
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %%
#Q3. handle missing values
df['Country'].unique()
# Out:
# array(['India', 'USA', 'UAS', 'Canada', nan, 'Russia'], dtype=object)

# %%
df["Country"].fillna(value=df["Country"].mode()[0],inplace=True)

# %%
df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018                  abc@gmail.com
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018                  cdf@gmail.com
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9   210.0            Jim Carry  01/01/1970             jimcarry@gmail.com
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %%
df['Country'].replace('UAS', 'USA', inplace=True)
df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018                  abc@gmail.com
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018                  cdf@gmail.com
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9   210.0            Jim Carry  01/01/1970             jimcarry@gmail.com
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  20 non-null     float64
#  1   Employee Full Name  20 non-null     object
#  2   DOB                 20 non-null     object
#  3   email               20 non-null     object
#  4   gender              20 non-null     object
#  5   Company             20 non-null     object
#  6   Country             20 non-null     object
#  7   Income.1            16 non-null     object
#  8   Income.2            18 non-null     float64
# dtypes: float64(2), object(7)
# memory usage: 1.5+ KB

# %%
df['Income.1'] = df['Income.1'].str.replace('$','')
# Out:
# C:\Users\Prashant Pathak\AppData\Local\Temp\ipykernel_6292\2869525772.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Income.1'] = df['Income.1'].str.replace('$','')

# %%
df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018                  abc@gmail.com
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018                  cdf@gmail.com
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9   210.0            Jim Carry  01/01/1970             jimcarry@gmail.com
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %%
df['Income.1'] = df['Income.1'].apply(pd.to_numeric, errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  20 non-null     float64
#  1   Employee Full Name  20 non-null     object
#  2   DOB                 20 non-null     object
#  3   email               20 non-null     object
#  4   gender              20 non-null     object
#  5   Company             20 non-null     object
#  6   Country             20 non-null     object
#  7   Income.1            13 non-null     float64
#  8   Income.2            18 non-null     float64
# dtypes: float64(3), object(6)
# memory usage: 1.5+ KB

# %%
df["Income.1"].fillna(value=df["Income.1"].mean(),inplace=True)
df["Income.2"].fillna(value=df["Income.2"].mean(),inplace=True)

# %%
df["Total_income"]=df["Income.1"]+df["Income.2"]

# %%
df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018                  abc@gmail.com
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018                  cdf@gmail.com
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9   210.0            Jim Carry  01/01/1970             jimcarry@gmail.com
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %% [markdown]
# # 15 SEP 2023
# Q1. Bring DOB in the same format
#
# q2. Split full name into first and last name in to two columns
#
# q3. move columns first and last name to the first and second position
#
# q4. print country and companywise average salary of employees.

# %%
df['DOB'] = pd.to_datetime(df['DOB'], errors='coerce')

# %%
df['DOB'] = df['DOB'].dt.strftime("%m/%d/%Y")
df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02/12/2018            spound0@spotify.com
# 1   202.0       Madelene Lutas  09/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier  09/29/2018                  abc@gmail.com
# 4   205.0       Jillana Physic  04/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman  04/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson  03/28/2018                  cdf@gmail.com
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn  01/16/2018               nwarn8@sogou.com
# 9   210.0            Jim Carry  01/01/1970             jimcarry@gmail.com
# 10  211.0       Charleen Auden  04/15/2018                caudena@nba.com
# 11  212.0          Dame Povele  06/26/2018         dpoveleb@bloglovin.com
# ...

# %%
df['First Name']=df['Employee Full Name'].str.split().str[0]
df['Last Name']=df['Employee Full Name'].str.split().str[-1]

# %%
df.drop(['Employee Full Name'],axis=1)
# Out:
#        id         DOB                          email  gender    Company  \
# 0   201.0  02/12/2018            spound0@spotify.com    Male     Google
# 1   202.0  09/20/2018                 mlutas1@si.edu  Female     Amazon
# 2   203.0  11/18/2018   dswanbourne2@istockphoto.com  Female      Intel
# 3   204.0  09/29/2018                  abc@gmail.com    Male  Accenture
# 4   205.0  04/19/2018        jphysic4@yellowbook.com  Female  Accenture
# 5   206.0  04/26/2018        ayokelman5@berkeley.edu  Female      Intel
# 6   207.0  03/28/2018                  cdf@gmail.com  Female      Intel
# 7   208.0  12/18/2017               mboon7@weibo.com    Male     Amazon
# 8   209.0  01/16/2018               nwarn8@sogou.com  Female     Amazon
# 9   210.0  01/01/1970             jimcarry@gmail.com    Male     Amazon
# 10  211.0  04/15/2018                caudena@nba.com  Female  Accenture
# 11  212.0  06/26/2018         dpoveleb@bloglovin.com    Male     Amazon
# ...

# %%
df.columns
# Out:
# Index(['id', 'Employee Full Name', 'DOB', 'email', 'gender', 'Company',
#        'Country', 'Income.1', 'Income.2', 'Total_income', 'First Name',
#        'Last Name'],
#       dtype='object')

# %%
df=df[['id','First Name', 'Last Name', 'DOB', 'email', 'gender', 'Company',
       'Country', 'Income.1', 'Income.2', 'Total_income']]

# %%
df
# Out:
#        id First Name    Last Name         DOB                          email  \
# 0   201.0      Salim        Pound  02/12/2018            spound0@spotify.com
# 1   202.0   Madelene        Lutas  09/20/2018                 mlutas1@si.edu
# 2   203.0      Dolli   Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0     Graeme     Croisier  09/29/2018                  abc@gmail.com
# 4   205.0    Jillana       Physic  04/19/2018        jphysic4@yellowbook.com
# 5   206.0     Anetta     Yokelman  04/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta    Batterson  03/28/2018                  cdf@gmail.com
# 7   208.0     Melina         Boon  12/18/2017               mboon7@weibo.com
# 8   209.0       Nomi         Warn  01/16/2018               nwarn8@sogou.com
# 9   210.0        Jim        Carry  01/01/1970             jimcarry@gmail.com
# 10  211.0   Charleen        Auden  04/15/2018                caudena@nba.com
# ...

# %%
df_grouped = df.groupby('Country').mean()[['Total_income']].sort_values('Total_income', ascending=False)

# %%
# Avg total income of each country
df_grouped
# Out:
#          Total_income
# Country
# Canada   49536.583972
# India    46992.703766
# USA      44439.100356
# Russia   32706.557135
